# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\lumm\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\lumm\anaconda3\lib\site-packages (from statsmodels) (1.24.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\lumm\anaconda3\lib\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in c:\users\lumm\anaconda3\lib\site-packages (from statsmodels) (1.2.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\lumm\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\lumm\anaconda3\lib\site-packages (from statsmodels) (23.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lumm\anaconda3\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lumm\anaconda3\lib\site-packages (from pandas>=1.0->statsmodels) (2022.7)
# Requirement already satisfied: six in c:\users\lumm\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from datetime import datetime

# Baca dataset
customer_data = pd.read_csv('Case-Study-Customer.csv')
store_data = pd.read_csv('Case-Study-Store.csv')
product_data = pd.read_csv('Case-Study-Product.csv')
transaction_data = pd.read_csv('Case-Study-Transaction.csv')

# %%
customer_data.head()
# Out:
#    CustomerID  Age  Gender Marital Status Income
# 0           1   55       1        Married   5,12
# 1           2   60       1        Married   6,23
# 2           3   32       1        Married   9,17
# 3           4   31       1        Married   4,87
# 4           5   58       1        Married   3,57

# %%
store_data.head()
# Out:
#    StoreID         StoreName GroupStore           Type   Latitude   Longitude
# 0        1     Prima Tendean      Prima   Modern Trade       -6,2  106,816666
# 1        2  Prima Kelapa Dua      Prima   Modern Trade  -6,914864  107,608238
# 2        3        Prima Kota      Prima   Modern Trade  -7,797068  110,370529
# 3        4       Gita Ginara       Gita  General Trade  -6,966667  110,416664
# 4        5           Bonafid       Gita  General Trade  -7,250445  112,768845

# %%
product_data.head()
# Out:
#   ProductID   Product Name  Price
# 0        P1      Choco Bar   8800
# 1        P2  Ginger Candy    3200
# 2        P3       Crackers   7500
# 3        P4    Potato Chip  12000
# 4        P5       Thai Tea   4200

# %%
transaction_data.head()
# Out:
#   TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 0       TR11369         328  01/01/2022        P3   7500    4        30000
# 1       TR16356         165  01/01/2022        P9  10000    7        70000
# 2        TR1984         183  01/01/2022        P1   8800    4        35200
# 3       TR35256         160  01/01/2022        P1   8800    7        61600
# 4       TR41231         386  01/01/2022        P9  10000    1        10000
#
#    StoreID
# 0       12
# 1        1
# 2        4
# 3        4
# 4        4

# %%
customer_data.tail()
# Out:
#      CustomerID  Age  Gender Marital Status Income
# 442         443   33       1            NaN   9,28
# 443         444   53       0        Married  15,31
# 444         445   51       0        Married  14,48
# 445         446   57       0        Married   7,81
# 446         447   54       1        Married  20,37

# %%
store_data.tail()
# Out:
#     StoreID       StoreName    GroupStore           Type   Latitude  \
# 9        10    Harapan Baru  Harapan Baru  General Trade   3,597031
# 10       11   Sinar Harapan      Prestasi  General Trade   0,533505
# 11       12  Prestasi Utama      Prestasi  General Trade  -2,990934
# 12       13           Buana         Buana  General Trade   -1,26916
# 13       14        Priangan      Priangan   Modern Trade      -5,45
#
#      Longitude
# 9    98,678513
# 10  101,447403
# 11  104,756554
# 12  116,825264
# 13   105,26667

# %%
product_data.tail()
# Out:
#   ProductID  Product Name  Price
# 5        P6        Cashew  18000
# 6        P7  Coffee Candy   9400
# 7        P8           Oat  16000
# 8        P9       Yoghurt  10000
# 9       P10  Cheese Stick  15000

# %%
transaction_data.tail()
# Out:
#      TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 5015       TR54423         243  31/12/2022       P10  15000    5        75000
# 5016        TR5604         271  31/12/2022        P2   3200    4        12800
# 5017       TR81224          52  31/12/2022        P7   9400    6        56400
# 5018       TR85016          18  31/12/2022        P8  16000    3        48000
# 5019       TR85684          55  31/12/2022        P8  16000    1        16000
#
#       StoreID
# 5015        3
# 5016        9
# 5017        9
# 5018       13
# 5019        6

# %%
customer_data.describe()
# Out:
#        CustomerID         Age      Gender
# count  447.000000  447.000000  447.000000
# mean   224.000000   39.782998    0.458613
# std    129.182042   12.848719    0.498842
# min      1.000000    0.000000    0.000000
# 25%    112.500000   30.000000    0.000000
# 50%    224.000000   39.000000    0.000000
# 75%    335.500000   50.500000    1.000000
# max    447.000000   72.000000    1.000000

# %%
store_data.describe()
# Out:
#        StoreID
# count  14.0000
# mean    7.5000
# std     4.1833
# min     1.0000
# 25%     4.2500
# 50%     7.5000
# 75%    10.7500
# max    14.0000

# %%
product_data.describe()
# Out:
#               Price
# count     10.000000
# mean   10410.000000
# std     4890.455557
# min     3200.000000
# 25%     7825.000000
# 50%     9700.000000
# 75%    14250.000000
# max    18000.000000

# %%
transaction_data.describe()
# Out:
#         CustomerID         Price          Qty   TotalAmount      StoreID
# count  5020.000000   5020.000000  5020.000000   5020.000000  5020.000000
# mean    221.263745   9684.800797     3.644622  32279.482072     7.489841
# std     129.672955   4600.708780     1.855295  19675.462455     4.028502
# min       1.000000   3200.000000     1.000000   7500.000000     1.000000
# 25%     108.000000   4200.000000     2.000000  16000.000000     4.000000
# 50%     221.000000   9400.000000     3.000000  28200.000000     7.000000
# 75%     332.000000  15000.000000     5.000000  47000.000000    11.000000
# max     447.000000  18000.000000    10.000000  88000.000000    14.000000

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      447 non-null    int64
#  1   Age             447 non-null    int64
#  2   Gender          447 non-null    int64
#  3   Marital Status  444 non-null    object
#  4   Income          447 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 17.6+ KB

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StoreID     14 non-null     int64
#  1   StoreName   14 non-null     object
#  2   GroupStore  14 non-null     object
#  3   Type        14 non-null     object
#  4   Latitude    14 non-null     object
#  5   Longitude   14 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 800.0+ bytes

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     10 non-null     object
#  1   Product Name  10 non-null     object
#  2   Price         10 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes

# %%
transaction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  5020 non-null   object
#  1   CustomerID     5020 non-null   int64
#  2   Date           5020 non-null   object
#  3   ProductID      5020 non-null   object
#  4   Price          5020 non-null   int64
#  5   Qty            5020 non-null   int64
#  6   TotalAmount    5020 non-null   int64
#  7   StoreID        5020 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 313.9+ KB

# %%
customer_data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Marital Status', 'Income'], dtype='object')

# %%
store_data.columns
# Out:
# Index(['StoreID', 'StoreName', 'GroupStore', 'Type', 'Latitude', 'Longitude'], dtype='object')

# %%
product_data.columns
# Out:
# Index(['ProductID', 'Product Name', 'Price'], dtype='object')

# %%
transaction_data.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'Date', 'ProductID', 'Price', 'Qty',
#        'TotalAmount', 'StoreID'],
#       dtype='object')

# %%
#DATA CLEANING

customer_data.isnull()
# Out:
#      CustomerID    Age  Gender  Marital Status  Income
# 0         False  False   False           False   False
# 1         False  False   False           False   False
# 2         False  False   False           False   False
# 3         False  False   False           False   False
# 4         False  False   False           False   False
# ..          ...    ...     ...             ...     ...
# 442       False  False   False            True   False
# 443       False  False   False           False   False
# 444       False  False   False           False   False
# 445       False  False   False           False   False
# 446       False  False   False           False   False
#
# [447 rows x 5 columns]

# %%
customer_data.isnull().sum()
# Out:
# CustomerID        0
# Age               0
# Gender            0
# Marital Status    3
# Income            0
# dtype: int64

# %%
mode_marital = customer_data['Marital Status'].mode()[0]
customer_data['Marital Status'] = customer_data['Marital Status'].fillna(mode_marital)

# %%
customer_data.isnull().sum()
# Out:
# CustomerID        0
# Age               0
# Gender            0
# Marital Status    0
# Income            0
# dtype: int64

# %%
store_data.isnull().sum()
# Out:
# StoreID       0
# StoreName     0
# GroupStore    0
# Type          0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
product_data.isnull().sum()
# Out:
# ProductID       0
# Product Name    0
# Price           0
# dtype: int64

# %%
transaction_data.isnull().sum()
# Out:
# TransactionID    0
# CustomerID       0
# Date             0
# ProductID        0
# Price            0
# Qty              0
# TotalAmount      0
# StoreID          0
# dtype: int64

# %%
# Gabungkan dataset-store, dataset-customer, dataset-product, dan dataset-transaction

merged_data = transaction_data.merge(store_data, on='StoreID')
merged_data = merged_data.merge(customer_data, on='CustomerID')
merged_data = merged_data.merge(product_data, on='ProductID')

# %%
merged_data['Date'] = pd.to_datetime(merged_data['Date'])

# %%
# Contoh: Membuat dataset baru untuk regresi
regression_data = merged_data.groupby('Date')['Qty'].sum().reset_index()

# %%
merged_data
# Out:
#      TransactionID  CustomerID       Date ProductID  Price_x  Qty  \
# 0          TR11369         328 2022-01-01        P3     7500    4
# 1          TR93280         287 2022-05-07        P3     7500    3
# 2          TR24817         287 2022-12-01        P3     7500    1
# 3           TR6865         233 2022-08-16        P3     7500    5
# 4           TR6445         181 2022-10-01        P3     7500    4
# ...            ...         ...        ...       ...      ...  ...
# 5015       TR29921         228 2022-11-02        P6    18000    2
# 5016       TR22734         228 2022-04-20        P6    18000    4
# 5017       TR99324         292 2022-08-27        P6    18000    3
# 5018        TR2963         113 2022-02-06        P6    18000    4
# 5019       TR39448         437 2022-07-21        P6    18000    2
#
#       TotalAmount  StoreID       StoreName    GroupStore           Type  \
# 0           30000       12  Prestasi Utama      Prestasi  General Trade
# 1           22500        7     Buana Indah         Buana  General Trade
# 2            7500        8   Sinar Harapan  Harapan Baru  General Trade
# 3           37500        7     Buana Indah         Buana  General Trade
# 4           30000       12  Prestasi Utama      Prestasi  General Trade
# ...           ...      ...             ...           ...            ...
# 5015        36000        7     Buana Indah         Buana  General Trade
# 5016        72000       11   Sinar Harapan      Prestasi  General Trade
# 5017        54000        9          Lingga        Lingga   Modern Trade
# 5018        72000        3      Prima Kota         Prima   Modern Trade
# 5019        36000       11   Sinar Harapan      Prestasi  General Trade
#
#        Latitude   Longitude  Age  Gender Marital Status Income Product Name  \
# 0     -2,990934  104,756554   36       0        Married  10,53     Crackers
# 1      3,316694  114,590111   36       0         Single    3,7     Crackers
# 2       5,54829   95,323753   36       0         Single    3,7     Crackers
# 3      3,316694  114,590111   43       1        Married   5,69     Crackers
# 4     -2,990934  104,756554   33       1        Married   9,94     Crackers
# ...         ...         ...  ...     ...            ...    ...          ...
# 5015   3,316694  114,590111   46       0        Married  11,31       Cashew
# 5016   0,533505  101,447403   46       0        Married  11,31       Cashew
# 5017  -3,654703  128,190643   31       0         Single   9,57       Cashew
# 5018  -7,797068  110,370529   57       0        Married   71,3       Cashew
# 5019   0,533505  101,447403   33       1        Married   3,49       Cashew
#
#       Price_y
# 0        7500
# 1        7500
# 2        7500
# 3        7500
# 4        7500
# ...       ...
# 5015    18000
# 5016    18000
# 5017    18000
# 5018    18000
# 5019    18000
#
# [5020 rows x 19 columns]

# %%
# Memisahkan data numeric dan categorical untuk memudahkan klasifikasi data
numeric = ['Date', 'Price_x', 'Qty', 'TotalAmount', 'StoreID', 'Latitude', 'Longitude', 'Age', 'Gender', 'Income', 'Price_y']
categorical = ['TransactionID', 'ProductID', 'StoreName', 'GroupStore', 'Type', 'Marital Status', 'Product Name']

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
merged_data['TransactionID'] = enc.fit_transform(merged_data['TransactionID'].values)
merged_data['ProductID'] = enc.fit_transform(merged_data['ProductID'].values)
merged_data['StoreName'] = enc.fit_transform(merged_data['StoreName'].values)
merged_data['GroupStore'] = enc.fit_transform(merged_data['GroupStore'].values)
merged_data['Type'] = enc.fit_transform(merged_data['Type'].values)
merged_data['Marital Status'] = enc.fit_transform(merged_data['Marital Status'].values)
merged_data['Product Name'] = enc.fit_transform(merged_data['Product Name'].values)

# %%
merged_data
# Out:
#       TransactionID  CustomerID       Date  ProductID  Price_x  Qty  \
# 0                66         328 2022-01-01          3     7500    4
# 1              4526         287 2022-05-07          3     7500    3
# 2               805         287 2022-12-01          3     7500    1
# 3              3175         233 2022-08-16          3     7500    5
# 4              2942         181 2022-10-01          3     7500    4
# ...             ...         ...        ...        ...      ...  ...
# 5015           1094         228 2022-11-02          6    18000    2
# 5016            690         228 2022-04-20          6    18000    4
# 5017           4867         292 2022-08-27          6    18000    3
# 5018           1080         113 2022-02-06          6    18000    4
# 5019           1622         437 2022-07-21          6    18000    2
#
#       TotalAmount  StoreID  StoreName  GroupStore  Type   Latitude  \
# 0           30000       12          6           4     0  -2,990934
# 1           22500        7          2           0     0   3,316694
# 2            7500        8         11           2     0    5,54829
# 3           37500        7          2           0     0   3,316694
# 4           30000       12          6           4     0  -2,990934
# ...           ...      ...        ...         ...   ...        ...
# 5015        36000        7          2           0     0   3,316694
# 5016        72000       11         11           4     0   0,533505
# 5017        54000        9          5           3     1  -3,654703
# 5018        72000        3          9           6     1  -7,797068
# 5019        36000       11         11           4     0   0,533505
#
#        Longitude  Age  Gender  Marital Status Income  Product Name  Price_y
# 0     104,756554   36       0               0  10,53             4     7500
# 1     114,590111   36       0               1    3,7             4     7500
# 2      95,323753   36       0               1    3,7             4     7500
# 3     114,590111   43       1               0   5,69             4     7500
# 4     104,756554   33       1               0   9,94             4     7500
# ...          ...  ...     ...             ...    ...           ...      ...
# 5015  114,590111   46       0               0  11,31             0    18000
# 5016  101,447403   46       0               0  11,31             0    18000
# 5017  128,190643   31       0               1   9,57             0    18000
# 5018  110,370529   57       0               0   71,3             0    18000
# 5019  101,447403   33       1               0   3,49             0    18000
#
# [5020 rows x 19 columns]

# %%
merged_data.describe()
# Out:
#        TransactionID   CustomerID    ProductID       Price_x          Qty  \
# count    5020.000000  5020.000000  5020.000000   5020.000000  5020.000000
# mean     2449.486454   221.263745     4.446813   9684.800797     3.644622
# std      1416.671962   129.672955     2.825213   4600.708780     1.855295
# min         0.000000     1.000000     0.000000   3200.000000     1.000000
# 25%      1223.750000   108.000000     2.000000   4200.000000     2.000000
# 50%      2449.500000   221.000000     5.000000   9400.000000     3.000000
# 75%      3674.250000   332.000000     7.000000  15000.000000     5.000000
# max      4907.000000   447.000000     9.000000  18000.000000    10.000000
#
#         TotalAmount      StoreID    StoreName   GroupStore         Type  \
# count   5020.000000  5020.000000  5020.000000  5020.000000  5020.000000
# mean   32279.482072     7.489841     5.830876     3.074502     0.432072
# std    19675.462455     4.028502     3.494664     2.088505     0.495414
# min     7500.000000     1.000000     0.000000     0.000000     0.000000
# 25%    16000.000000     4.000000     3.000000     1.000000     0.000000
# 50%    28200.000000     7.000000     5.000000     3.000000     0.000000
# 75%    47000.000000    11.000000     9.000000     5.000000     1.000000
# max    88000.000000    14.000000    11.000000     6.000000     1.000000
#
#                Age       Gender  Marital Status  Product Name       Price_y
# count  5020.000000  5020.000000     5020.000000   5020.000000   5020.000000
# mean     40.003586     0.452988        0.238446      4.830677   9684.800797
# std      12.834719     0.497835        0.426176      2.805726   4600.708780
# min       0.000000     0.000000        0.000000      0.000000   3200.000000
# 25%      30.000000     0.000000        0.000000      2.000000   4200.000000
# 50%      39.000000     0.000000        0.000000      5.000000   9400.000000
# 75%      51.000000     1.000000        0.000000      8.000000  15000.000000
# max      72.000000     1.000000        1.000000      9.000000  18000.000000

# %%
import matplotlib.pyplot as plt

# Plot scatter plot
plt.scatter(merged_data['Product Name'], merged_data['Qty'])
plt.xlabel('Product Name')
plt.ylabel('Qty')

# Mengatur posisi dan label pada sumbu x
plt.xticks(rotation=90)  # Memutar label pada sumbu x sebesar 90 derajat

plt.show()

# %%
plt.scatter(merged_data['Date'], merged_data['Qty'])
plt.xlabel('Date')
plt.ylabel('Qty')

# Mengatur posisi dan label pada sumbu x
plt.xticks(rotation=90)  # Memutar label pada sumbu x sebesar 90 derajat

plt.show()

# %%
merged_data.corr()
# Out:
#                 TransactionID  CustomerID  ProductID   Price_x       Qty  \
# TransactionID        1.000000    0.005830  -0.025274 -0.139298  0.044812
# CustomerID           0.005830    1.000000  -0.027999 -0.016423 -0.009755
# ProductID           -0.025274   -0.027999   1.000000  0.182064 -0.240724
# Price_x             -0.139298   -0.016423   0.182064  1.000000 -0.353640
# Qty                  0.044812   -0.009755  -0.240724 -0.353640  1.000000
# TotalAmount         -0.059170   -0.024915  -0.060560  0.440632  0.621129
# StoreID              0.001892    0.004129   0.007865 -0.032863  0.014365
# StoreName            0.008079    0.018977  -0.030566 -0.006843  0.030493
# GroupStore           0.012698    0.010763  -0.021412  0.014293  0.029202
# Type                 0.011518   -0.000866  -0.017529  0.030960  0.016218
# Age                 -0.012268   -0.025952  -0.005632  0.014693 -0.027768
# Gender               0.016461   -0.009947   0.027333  0.010705 -0.010542
# Marital Status       0.003410    0.122229  -0.023967 -0.005498 -0.007966
# Product Name         0.055768    0.005066   0.541990 -0.450838 -0.041455
# Price_y             -0.139298   -0.016423   0.182064  1.000000 -0.353640
#
#                 TotalAmount   StoreID  StoreName  GroupStore      Type  \
# TransactionID     -0.059170  0.001892   0.008079    0.012698  0.011518
# CustomerID        -0.024915  0.004129   0.018977    0.010763 -0.000866
# ProductID         -0.060560  0.007865  -0.030566   -0.021412 -0.017529
# Price_x            0.440632 -0.032863  -0.006843    0.014293  0.030960
# Qty                0.621129  0.014365   0.030493    0.029202  0.016218
# TotalAmount        1.000000 -0.010722   0.012364    0.033158  0.037976
# StoreID           -0.010722  1.000000  -0.154760   -0.303692 -0.367429
# StoreName          0.012364 -0.154760   1.000000    0.750284  0.370546
# GroupStore         0.033158 -0.303692   0.750284    1.000000  0.728940
# Type               0.037976 -0.367429   0.370546    0.728940  1.000000
# Age               -0.016900 -0.003872  -0.000004   -0.015032 -0.005947
# Gender            -0.008774 -0.000189  -0.014477   -0.001038 -0.001237
# Marital Status    -0.004886  0.012958  -0.018670   -0.021082 -0.014334
# Product Name      -0.360963  0.037518  -0.022693   -0.032801 -0.029491
# Price_y            0.440632 -0.032863  -0.006843    0.014293  0.030960
#
#                      Age    Gender  Marital Status  Product Name   Price_y
# TransactionID  -0.012268  0.016461        0.003410      0.055768 -0.139298
# CustomerID     -0.025952 -0.009947        0.122229      0.005066 -0.016423
# ProductID      -0.005632  0.027333       -0.023967      0.541990  0.182064
# Price_x         0.014693  0.010705       -0.005498     -0.450838  1.000000
# Qty            -0.027768 -0.010542       -0.007966     -0.041455 -0.353640
# TotalAmount    -0.016900 -0.008774       -0.004886     -0.360963  0.440632
# StoreID        -0.003872 -0.000189        0.012958      0.037518 -0.032863
# StoreName      -0.000004 -0.014477       -0.018670     -0.022693 -0.006843
# GroupStore     -0.015032 -0.001038       -0.021082     -0.032801  0.014293
# Type           -0.005947 -0.001237       -0.014334     -0.029491  0.030960
# Age             1.000000 -0.033183       -0.449576     -0.003419  0.014693
# Gender         -0.033183  1.000000        0.023264      0.043084  0.010705
# Marital Status -0.449576  0.023264        1.000000     -0.008885 -0.005498
# Product Name   -0.003419  0.043084       -0.008885      1.000000 -0.450838
# Price_y         0.014693  0.010705       -0.005498     -0.450838  1.000000

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot ACF dan PACF
plot_acf(merged_data['Qty'], lags=40)
plot_pacf(merged_data['Qty'], lags=40)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(merged_data['Qty'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:')
for key, value in result[4].items():
    print(f'   {key}: {value}')

# Jika p-value kurang dari 0.05, kita dapat menganggap data stasioner
# Out:
# ADF Statistic: -3.4282570301480604
# p-value: 0.010032490769942996
# Critical Values:
#    1%: -3.431661944885779
#    5%: -2.8621197374408225
#    10%: -2.5670785949998973

# %%
from statsmodels.tsa.arima.model import ARIMA

# Contoh: ARIMA(1,1,1)
model = ARIMA(merged_data['Qty'], order=(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    Qty   No. Observations:                 5020
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -9357.694
# Date:                Fri, 29 Sep 2023   AIC                          18721.389
# Time:                        10:00:06   BIC                          18740.952
# Sample:                             0   HQIC                         18728.244
#                                - 5020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0118      0.013     -0.933      0.351      -0.036       0.013
# ma.L1         -0.9487      0.004   -237.185      0.000      -0.957      -0.941
# sigma2         2.4365      0.053     45.745      0.000       2.332       2.541
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                27.04
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Pisahkan data menjadi data pelatihan dan pengujian
train_size = int(len(merged_data) * 0.8)
train, test = merged_data[:train_size], merged_data[train_size:]

# Latih model
model = ARIMA(train['Qty'], order=(1,1,1))
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    Qty   No. Observations:                 5020
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -9357.694
# Date:                Fri, 29 Sep 2023   AIC                          18721.389
# Time:                        10:00:55   BIC                          18740.952
# Sample:                             0   HQIC                         18728.244
#                                - 5020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0118      0.013     -0.933      0.351      -0.036       0.013
# ma.L1         -0.9487      0.004   -237.185      0.000      -0.957      -0.941
# sigma2         2.4365      0.053     45.745      0.000       2.332       2.541
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                27.04
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Prediksi menggunakan model
predictions = model_fit.predict(start=len(train), end=len(train) + len(test)-1, typ='levels')

# Hitung RMSE (Root Mean Squared Error)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test['Qty'], predictions))
print('RMSE:', rmse)
# Out:
# RMSE: 1.4139188905356488

# %%
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['Qty'], label='Data Asli')
plt.plot(test.index, predictions, color='red', label='Prediksi')
plt.legend()
plt.title('Hasil Prediksi ARIMA')
plt.xlabel('Product')
plt.ylabel('Qty')
plt.show()
